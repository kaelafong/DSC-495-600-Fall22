# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
artists = pd.read_csv('artists.csv')
works = pd.read_csv('artworks.csv')
#df = pd.read_csv("museums.csv")

# %% [markdown]
# # Narrative Analytics Guided Example
#
# Here we're going to dive into a dataset and perform some analytics, The Museum of Modern Art ([MoMA](https://www.moma.org/)) acquired its first artworks in 1929, the year it was established. Today, the Museum’s evolving collection contains almost 200,000 works from around the world spanning the last 150 years. Also note that data and guided example makes a decent example for your capstone report.
#
#
# # The Museum of Modern Art Collection Data Exploration
#
# ## Data
#
# We will be working with the Museum of [Modern Art Collection](https://www.kaggle.com/datasets/momanyc/museum-collection?select=artworks.csv) dataset of artists and artworks. This data was released by the MoMa.
#
# For our purposes we are going to assume that it is representative of their larger collection and that it is also therefore representative of the MoMa's art collecting in general post 1200 (the earliest acquisition in this dataset was acquired in 1216).
#
# The dataset itself consists of 2 tables, artists and artworks.
#
# The artists dataset contains 15,091 records, representing all the artists who have work in MoMA's collection and have been cataloged in our database. It includes basic metadata for each artist, including name, nationality, gender, birth year, and death year.
#
# The artworks dataset contains 130,262 records, representing all of the works that have been accessioned into MoMA’s collection and cataloged in our database. It includes basic metadata for each work, including title, artist, date, medium, dimensions, and date acquired by the Museum. Some of these records have incomplete information and are noted as “not curator approved.”

# %% [markdown]
# ## Analytic Questions
#
# __ #1 Who are the most popular artists in the MoMa Collection? Are there any outliers in terms of amount collected?__
#
# Let's start with a simple question about popularity. Which artists and time periods has the MoMa prioritized collecting? First we'll approach artists.

# %%
works.Name.value_counts().head(20).plot(kind='bar')
plt.ylabel('Artworks Count')
plt.show()

# %% [markdown]
# This plot of artworks by artists for the top 20 artists really only shows us one thing (other than providing a list of the 20 most popular artists): The MoMa has a lot of works by Eugène Atget.
#
# Eugène Atget was a French flâneur and a pioneer of documentary photography, noted for his determination to document all of the architecture and street scenes of Paris before their disappearance to modernization. Most of his photographs were first published by Berenice Abbott after his death. It makes up a large portion of the MoMa's museum in New York.
#
# To look at the relative popularity of other artists let's remove Eugène Atget.

# %%
works.Name.value_counts().head(50)[1:51].plot(kind='bar', figsize=(10,5))
plt.ylabel('Artworks Count')
plt.show()

# %% [markdown]
# So there seem to be a few other exceptionally popular artists, with the first four or arguably six being collected in meaningfully larger numbers.
#
# _Remember, this is popularity in terms of pieces collected. We have no data about visits or webviews._

# %% [markdown]
# __ #2 Who are the artists in the MoMa's collection? How does that vary by geography, age, and living or dead?__

# %% [markdown]
# So there are 15,091 artists in the MoMa's collection. Where are they from? When looking into the `placeOfBirth` variable, there is a challenge, however. The format is inconsistent. Sometimes the birthplace includes a city, others just a country.

# %%
# Process data to create counts by country

# Split the Nationality on commas in case there is two of them
locations = artists.Nationality.str.split(',', 1).tolist()
locations = [x for x in locations if str(x) != 'nan']
nationalities = []

# Process countries and clean up text
for entry in locations:
    c = entry[-1]
    c = c.strip()
    nationalities.append(c)
nationalities = pd.DataFrame(nationalities, columns=['nationality'])

# Create numeric counts
cntry_counts = pd.DataFrame(nationalities.nationality.value_counts())
other = int(cntry_counts[10:].sum())
cntry_counts = cntry_counts[:10]
cntry_counts.loc[11] = other
cntry_counts = cntry_counts.rename(index={11: 'Other'})

# Generate Pie Chart
plt.figure(figsize=(10, 5))
plt.pie(cntry_counts.nationality)
plt.axis('equal')
plt.title('Artists Nationality')
plt.legend(cntry_counts.index)
plt.show()

# %% [markdown]
# So, about half of the artists in the collection are from the US, which again is not hugely surprising as this is a American collection. The two things of note we see here are that the Japan is the only Asian country in the top 10. Also, the other countries selection is quite large, with a very large number of countries having some representation in the MoMa collection and making up more than a quarter of their collection.

# %%
plt.plot(artists['Birth Year'].value_counts().sort_index())
plt.title('Artists Born by Year')
plt.show()

# %% [markdown]
# You can see that the closer to modern times we get, the more artists we have represented. You see some interesting peaks around the centuries that are perhaps worthy of further investigation. Maybe they're using something other than artist's names to talk about movements?
#
# How does this compare to when artworks were acquired?

# %%
# Split the 'Acquisition Date' on "-" 
works['acquisitionYear']= works['Acquisition Date'].str.split('-', 1).str[:1]

# %%
works['acquisitionYear'] = works['acquisitionYear'].str[0]#.fillna(0).astype(int)

# %%
acquisition_df = pd.DataFrame(works.acquisitionYear.value_counts())
acquisition_df = acquisition_df.sort_index()
plt.plot(acquisition_df)
plt.ylabel('Works Acquired')
plt.show()

# %% [markdown]
# This shows a collection that seems to have several peaks in its growth. That is consistent with how museum collections tend to grow. While there is some steady acquisition, which is somewhat visible in the more modern years (though this is not a great visual of that), museums tend to see the majority of their growth from large gifts or bequests.  What does it look like without Eugène Atget and to see the years clearly?

# %%
#convert to integer
works['acquisitionYear']= works['acquisitionYear'].fillna(0).astype(int)

# %%
plt.plot(works[works['acquisitionYear']>=1900].acquisitionYear.value_counts().sort_index(), label='Works Acquired')
plt.ylabel('Works Acquired')
plt.show()

# %%
acquisition_df = pd.DataFrame(works[(works.acquisitionYear>=1960) & (works.Name != 'Eugène Atget')].acquisitionYear.value_counts())
acquisition_df = acquisition_df.sort_index()
plt.plot(acquisition_df)
plt.ylabel('Works Acquired')
plt.show()

# %% [markdown]
# This shows a few more clear spikes but also a clear narrative that the collection has been growing more rapidly in recent years. This aligns with the skew towards contemporary artists.

# %% [markdown]
# Let's move on to one last subject: determining the portion of the artists who are living. For this, we'll use year of death as an indicator.

# %%
living = pd.DataFrame(artists['Death Year'].isnull())
living = pd.DataFrame(living['Death Year'].value_counts())
living.plot(kind='bar', legend=False)
plt.title('Artists Who are No Longer Living')
# Out:
# Text(0.5, 1.0, 'Artists Who are No Longer Living')

# %% [markdown]
# This shows a surprisingly large portion of the artists collected by the MoMa are dead.

# %% [markdown]
# __#3 What are the most popular mediums and how does medium affect size?__

# %% [markdown]
# So it would be tempting to start with medium just as the data provides it. However, this reveals a bit of a problem.

# %%
works.Medium.value_counts().head(10)
# Out:
# Gelatin silver print            14103
# Lithograph                       7034
# Albumen silver print             4845
# Lithograph, printed in color     1833
# Pencil on paper                  1725
# Etching                          1710
# Lithograph, printed in black     1523
# Chromogenic color print          1488
# Letterpress                      1420
# Ink on paper                     1388
# Name: Medium, dtype: int64

# %% [markdown]
# There are way too many kinds of medium, and with a level of subtlety that we don't really want. We'll group some together.
#
# We're also dropping Turner here because he has 25,000 works on paper that skew all counts towards that.

# %%
# Remove Atget
Atgetless_artworks = works[works['Name'] != 'Eugène Atget']
# Coerce to Numeric
Atgetless_artworks['Height (cm)'] = pd.to_numeric(Atgetless_artworks['Height (cm)'], errors = 'coerce')
Atgetless_artworks['Width (cm)'] = pd.to_numeric(Atgetless_artworks['Width (cm)'], errors = 'coerce')
Atgetless_artworks['Depth (cm)'] = pd.to_numeric(Atgetless_artworks['Depth (cm)'], errors = 'coerce')
#Atgetless_artworks = Atgetless_artworks[Atgetless_artworks['units']=='mm']
Atgetless_artworks = Atgetless_artworks[Atgetless_artworks['Height (cm)'].notnull()]

## The error is just because of how we did the conditional select and we don't need to be worried about it...
# Out:
# C:\Users\kaela\AppData\Local\Temp\ipykernel_11860\183949630.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Atgetless_artworks['Height (cm)'] = pd.to_numeric(Atgetless_artworks['Height (cm)'], errors = 'coerce')
# C:\Users\kaela\AppData\Local\Temp\ipykernel_11860\183949630.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Atgetless_artworks['Width (cm)'] = pd.to_numeric(Atgetless_artworks['Width (cm)'], errors = 'coerce')
# C:\Users\kaela\AppData\Local\Temp\ipykernel_11860\183949630.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Atgetless_artworks['Depth (cm)'] = pd.to_numeric(Atgetless_artworks['Depth (cm)'], errors = 'coerce')

# %%
# Aggregate to new medium_agg column
Atgetless_artworks['Medium_agg'] = 'other'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("paper", na=False),'medium_agg'] = 'paper'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("canvas", na=False),'medium_agg'] = 'canvas'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("wood", na=False),'medium_agg'] = 'wood'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("paint on", na=False),'medium_agg'] = 'other painted panel'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("Bronze", na=False),'medium_agg'] = 'sculpture'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("Plaster", na=False),'medium_agg'] = 'sculpture'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("Marble", na=False),'medium_agg'] = 'sculpture'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("Stone", na=False),'medium_agg'] = 'sculpture'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("plate", na=False),'medium_agg'] = 'plate'
Atgetless_artworks.loc[Atgetless_artworks['Medium'].str.contains("photograph", na=False),'medium_agg'] = 'photo'

Atgetless_artworks['surface'] = Atgetless_artworks['Height (cm)'] * Atgetless_artworks['Width (cm)']

# %%
Atgetless_artworks[['medium_agg','Height (cm)','Width (cm)','Depth (cm)','surface']].groupby('medium_agg').describe()
# Out:
#                     Height (cm)                                         \
#                           count        mean        std  min        25%
# medium_agg
# canvas                   1514.0  123.470422  71.618001  0.0  66.000000
# other painted panel       697.0  101.209968  91.651788  0.0  35.300000
# paper                   15857.0   41.615416  34.466611  0.0  21.844000
# photo                     413.0   40.454158  41.544112  0.0  20.320041
# plate                     552.0   48.005541  49.968616  0.0  18.800000
# sculpture                 357.0   75.446040  73.252889  0.0  27.900000
# wood                     2716.0   48.533109  55.363788  0.0  17.275000
#
#                                                    Width (cm)              \
#                         50%        75%         max      count        mean
# medium_agg
# canvas               102.95  175.40000   404.80000     1512.0  126.367180
# other painted panel   65.70  152.40000  1011.00000      695.0  115.379738
# paper                 31.80   50.80000  1097.30000    15837.0   46.692194
# photo                 28.00   46.00000   320.04064      412.0   51.836890
# plate                 30.25   70.87695   411.50000      493.0   60.527188
# sculpture             47.30  101.60000   450.00000      318.0   64.475169
# wood                  30.80   59.62500   609.60120     2656.0   47.971016
#
#                      ... Depth (cm)             surface                \
#                      ...        75%        max    count          mean
# medium_agg           ...
# canvas               ...     8.8250  405.13081   1512.0  20638.171154
# other painted panel  ...    13.7500  853.40000    695.0  19775.385281
# paper                ...     1.3000  270.00000  15837.0   3612.820589
# photo                ...     3.8000  525.80000    412.0   4196.429937
# plate                ...    59.0000  331.50000    493.0   7584.738616
# sculpture            ...    50.2738  632.00000    318.0   8627.599149
# wood                 ...    61.0000  602.00000   2656.0   4508.015499
#
#                                                                    \
#                               std  min          25%           50%
# medium_agg
# canvas               31832.318664  0.0  4524.600000  10273.820000
# other painted panel  37725.898869  0.0  1238.511587   5080.655323
# paper                80291.968266  0.0   578.250000   1013.100000
# photo                14717.697146  0.0   511.704610    868.242606
# plate                57272.208274  0.0   273.480000    881.640000
# sculpture            22451.864289  0.0   735.052500   1931.044998
# wood                 14071.093825  0.0   309.678039    800.203213
#
#
#                               75%           max
# medium_agg
# canvas               27726.070000  7.989722e+05
# other painted panel  19935.297239  3.597624e+05
# paper                 2903.231613  1.003371e+07
# photo                 2097.175000  1.982007e+05
# plate                 3967.741620  1.066067e+06
# sculpture             6906.170000  2.214105e+05
# wood                  3548.391938  2.589072e+05
#
# [7 rows x 32 columns]

# %%
Atgetless_artworks[['medium_agg', 'Height (cm)']].boxplot(by='medium_agg', figsize=(10,20))
plt.show()

# %%
Atgetless_artworks[Atgetless_artworks['Height (cm)']>1400]
# Out:
#         Artwork ID            Title            Artist ID  \
# 87538       101902          To Lift                 5349
# 91942       111576  Vitra Wallpaper  31022, 31023, 33830
# 112975      163921               11                37833
#
#                                                  Name  Date  \
# 87538                                   Richard Serra  1967
# 91942   Michael Rock, Susan Sellers, Georgianna Stout  2002
# 112975                               Mariah Robertson  2012
#
#                                            Medium  \
# 87538                           Vulcanized rubber
# 91942   Digital print from Adobe Illustrator File
# 112975                    Chromogenic color print
#
#                                        Dimensions Acquisition Date  \
# 87538   36" x 6' 8" x 60" (91.4 x 200 x 152.4 cm)       2007-10-01
# 91942                620 x 163" (1574.8 x 414 cm)       2007-11-07
# 112975                100' x 30" (3048 x 76.2 cm)       2012-10-02
#
#                                                    Credit Catalogue  ...  \
# 87538                                  Gift of the artist         Y  ...
# 91942                               Gift of the designers         Y  ...
# 112975  Acquired through the generosity of Thomas and ...         Y  ...
#
#         Height (cm) Length (cm)  Width (cm)  Depth (cm)  Weight (kg)  \
# 87538   9140.000000         NaN  200.000000    152.4003          NaN
# 91942   1574.803100         NaN  414.020800         NaN          NaN
# 112975  3048.006096         NaN   76.200152         NaN          NaN
#
#         Duration (s)  acquisitionYear  Medium_agg  medium_agg       surface
# 87538            NaN             2007       other         NaN  1.828000e+06
# 91942            NaN             2007       other         NaN  6.520012e+05
# 112975           NaN             2012       other         NaN  2.322585e+05
#
# [3 rows x 25 columns]

# %% [markdown]
# Now, that plot is so ghastly large that it's likely impossible to see all of it on a monitor at once. However, keeping it makes a point. There are some _exceptional_ outliers here. The most striking is a paper piece by Richard Serra measuring 91.4 meters high! We only included one of the plots, but it would be trivial to generate the same boxplot for width, depth, and surface area.
#
# __Do that and give me the outliers you found__
#
# However, the bottom part of the plot has more generally applicable conclusions to show. Plates are almost all the same size (this is things like copper plates by the way, not ceramic). Canvas is the largest in medium and 75th percentile, and therefore also the highest whisker.
#
# So as one would expect different mediums are generally different sizes but there is huge variation in the collection, so trying to predict medium off of size could be very difficult.

# %%
# For Width
Atgetless_artworks[['medium_agg', 'Width (cm)']].boxplot(by='medium_agg', figsize=(10,20))
plt.show()

# %%
Atgetless_artworks[Atgetless_artworks['Width (cm)']>1400]
# Out:
#         Artwork ID                                              Title  \
# 31985        33502                                    Untitled Object
# 33718        35639                                           Untitled
# 34941        37162                                           Untitled
# 35257        37539                                      Notes in Time
# 35437        37776  Cartoon for mosaic mural for William E. Grady ...
# 56031        59621                                    She Lost It (1)
# 74176        79805                                              F-111
# 75033        80990                                             Switch
# 75464        81514                                    Intersection II
# 75504        81557                         Sculpture for a Large Wall
# 79621        86815                                        Long Scroll
# 84493        96154                                            Printer
# 86483        98719                                            Candide
# 86844       100190                                           Rhapsody
# 90776       109222                  De Eetbare Stad / The Edible City
# 91412       110565  Gone: An Historical Romance of a Civil War as ...
# 92826       116271                                           Currents
# 129334      212955                           Tom’s database 1967-2015
#
#        Artist ID                 Name       Date  \
# 31985        902      James Lee Byars  (1962-64)
# 33718        902      James Lee Byars  (1962-64)
# 34941       2505         Keith Haring       1982
# 35257       5564          Nancy Spero     (1979)
# 35437       5366            Ben Shahn     (1956)
# 56031        710     Louise Bourgeois       1992
# 74176       5021     James Rosenquist    1964-65
# 75033       5349        Richard Serra       1999
# 75464       5349        Richard Serra    1992-93
# 75504       3048      Ellsworth Kelly    1956-57
# 79621      25465      Huang Yong Ping       2001
# 84493      28661          John Hodany    2001-02
# 86483      28981      Carole Benzaken       2004
# 86844        357    Jennifer Bartlett    1975-76
# 90776      32472  Experimental Jetset       2007
# 91412       7679          Kara Walker       1994
# 92826       4823  Robert Rauschenberg       1970
# 129334     61403      Yve Laris Cohen       2015
#
#                                                    Medium  \
# 31985         Crayon on Japanese paper, joined and folded
# 33718   Japanese handmade white flax paper, hinged and...
# 34941                          Ink on two sheets of paper
# 35257   Cut-and-pasted painted paper, gouache, and pen...
# 35437                                    Tempera on paper
# 56031                                         Screenprint
# 74176   Oil on canvas with aluminum, twenty-three sect...
# 75033                      Weatherproof steel, six plates
# 75464   Weatherproof steel, four identical conical sec...
# 75504                       Anodized aluminum, 104 panels
# 79621   Watercolor, pencil, colored pencil, and ink on...
# 84493   Installation of synthetic polymer paint on pap...
# 86483                                          Lithograph
# 86844                         Enamel on steel, 987 plates
# 90776                                          Lithograph
# 91412                                               Paper
# 92826                                         Screenprint
# 129334                                              Paper
#
#                                                Dimensions Acquisition Date  \
# 31985   unfolded 12" x 210' 9" (30.3 cm x 64.23 m); fo...       1965-02-09
# 33718   Folded: 36 x 36 x 3" (91 x 91 x 7.6 cm) Unfold...       1966-06-07
# 34941   Sheet: 72 x 671 1/2" (182.9 x 1705.6cm)\nPart ...       1992-11-05
# 35257   24 sheets Overall: 20 x 210' (50.8 x 6400.8 cm...       1998-10-29
# 35437               7' 8 1/2" x 49' 2 1/4" (2.34 x 15 m.)       1959-10-15
# 56031            sheet: 33 7/8 x 178' 4" (86 x 5435.6 cm)       1993-01-18
# 74176                        10 x 86' (304.8 x 2621.3 cm)       1996-10-07
# 75033      each 13' 6" x 52' x 2" (411.5 x 1585 x 5.1 cm)       2000-02-07
# 75464   Two sections 13' 1 1/2" (400 cm) high x 51' 9"...       1998-05-01
# 75504        11' 5" x 65' 5" x 28" (348 x 1994 x 71.1 cm)       1998-10-13
# 79621                    13 1/4 x 603" (33.7 x 1531.6 cm)       2002-10-15
# 84493   Installation: 39 x 684 x 23 1/2" (99.1 x 1737....       2005-05-10
# 86483        Sheet (unrolled): 2 x 66' 8" (5.1 x 2032 cm)       2005-06-02
# 86844   Each plate 12 x 12" (30.4 x 30.4 cm); overall ...       2005-10-06
# 90776                   23 3/8 x 1612" (59.4 x 4094.5 cm)       2007-06-05
# 91412                  Overall 13 x 50' (396.2 x 1524 cm)       2007-10-01
# 92826                sheet: 72 x 648" (182.9 x 1645.9 cm)       2008-03-12
# 129334                        150' × 36" (4572 × 91.4 cm)       2016-09-19
#
#                                                    Credit Catalogue  ...  \
# 31985                                  Gift of the artist         Y  ...
# 33718                                  Gift of the artist         Y  ...
# 34941            Gift of the Estate of Keith Haring, Inc.         Y  ...
# 35257                      Gift of Harriet and Rick Meyer         Y  ...
# 35437                                  Gift of the artist         Y  ...
# 56031                                  Gift of the artist         Y  ...
# 74176   Gift of Mr. and Mrs. Alex L. Hillman and Lilli...         Y  ...
# 75033          Gift of Emily Carroll and Thomas W. Weisel         Y  ...
# 75464              Gift of Jo Carole and Ronald S. Lauder         Y  ...
# 75504              Gift of Jo Carole and Ronald S. Lauder         Y  ...
# 79621                                            Purchase         Y  ...
# 84493   The Judith Rothschild Foundation Contemporary ...         Y  ...
# 86483                               Lily Auchincloss Fund         Y  ...
# 86844                            Gift of Edward R. Broida         Y  ...
# 90776                               Gift of the designers         Y  ...
# 91412   Gift of The Speyer Family Foundation in honor ...         Y  ...
# 92826                       Riva Castleman Endowment Fund         Y  ...
# 129334                              Gift of Sophie Mörner         N  ...
#
#         Height (cm) Length (cm)   Width (cm)  Depth (cm)    Weight (kg)  \
# 31985     30.500000         NaN  6423.700000         NaN            NaN
# 33718   1097.300000         NaN  9144.000000         NaN            NaN
# 34941    182.900000         NaN  1705.600000         NaN            NaN
# 35257     50.800100         NaN  6400.800000         NaN            NaN
# 35437    234.900000         NaN  1499.200000         NaN            NaN
# 56031     86.360173         NaN  5435.600000         NaN            NaN
# 74176    304.800000         NaN  2621.300000         NaN            NaN
# 75033    411.500000         NaN  1584.963200    5.100000  185067.585957
# 75464    400.000000         NaN  1700.200000    5.100000   27095.618253
# 75504    348.000000         NaN  1993.900000   71.100000            NaN
# 79621     33.655100         NaN  1531.623100         NaN            NaN
# 84493     99.060200         NaN  1737.363500   59.690100            NaN
# 86483      5.080000         NaN  2032.004100         NaN            NaN
# 86844    228.600500         NaN  4663.449300         NaN            NaN
# 90776     59.372600         NaN  4094.488200         NaN            NaN
# 91412    396.200000         NaN  1524.000000         NaN            NaN
# 92826    182.880366         NaN  1645.923292         NaN            NaN
# 129334     0.000000         NaN  4572.009144   91.440183            NaN
#
#         Duration (s)  acquisitionYear  Medium_agg           medium_agg  \
# 31985            NaN             1965       other                paper
# 33718            NaN             1966       other                paper
# 34941            NaN             1992       other                paper
# 35257            NaN             1998       other                paper
# 35437            NaN             1959       other                paper
# 56031            NaN             1993       other                  NaN
# 74176            NaN             1996       other               canvas
# 75033            NaN             2000       other                plate
# 75464            NaN             1998       other                  NaN
# 75504            NaN             1998       other                  NaN
# 79621            NaN             2002       other                paper
# 84493            NaN             2005       other  other painted panel
# 86483            NaN             2005       other                  NaN
# 86844            NaN             2005       other                plate
# 90776            NaN             2007       other                  NaN
# 91412            NaN             2007       other                  NaN
# 92826            NaN             2008       other                  NaN
# 129334           NaN             2016       other                  NaN
#
#              surface
# 31985   1.959229e+05
# 33718   1.003371e+07
# 34941   3.119542e+05
# 35257   3.251613e+05
# 35437   3.521621e+05
# 56031   4.694194e+05
# 74176   7.989722e+05
# 75033   6.522124e+05
# 75464   6.800800e+05
# 75504   6.938772e+05
# 79621   5.154693e+04
# 84493   1.721036e+05
# 86483   1.032258e+04
# 86844   1.066067e+06
# 90776   2.431004e+05
# 91412   6.038088e+05
# 92826   3.010071e+05
# 129334  0.000000e+00
#
# [18 rows x 25 columns]

# %%
# For Depth
Atgetless_artworks[['medium_agg', 'Depth (cm)']].boxplot(by='medium_agg', figsize=(10,20))
plt.show()

# %%
Atgetless_artworks[Atgetless_artworks['Depth (cm)']>120]
# Out:
#         Artwork ID                                              Title  \
# 862            968  Bridge of Houses Project, Melbourne, Australia...
# 864            970  Dr. Phillip M. Lovell House, Los Angeles, Cali...
# 869            975             A Dutch House, Holten, The Netherlands
# 871            978  Offices for Willis Faber & Dumas Ltd., Ipswich...
# 872            979  Offices for Willis Faber & Dumas Ltd., Ipswich...
# ...            ...                                                ...
# 126935      200325                        Emergency Temporary Shelter
# 126945      200389                                 CM-2 Supercomputer
# 128244      202872          City Edge, Cloud Prop (Competition model)
# 128809      204830                                       Child's Play
# 129350      214522                                       Altar/Engine
#
#                                      Artist ID  \
# 862     7609, 2702, 22705, 22709, 22710, 22713
# 864                                       4277
# 869                          6956, 22836, 8175
# 871                                       1953
# 872                                       1953
# ...                                        ...
# 126935                                   49237
# 126945                                   49257
# 128244                                    7527
# 128809                                    2281
# 129350                                   39961
#
#                                                      Name       Date  \
# 862     Steven Holl Architects, Steven Holl, Mark Jans...    1979-82
# 864                                        Richard Neutra    1927-29
# 869              Rem Koolhaas, Gro Bonesmo, Jeroen Thomas       1993
# 871                                     Foster Associates    1970-75
# 872                                     Foster Associates    1970-75
# ...                                                   ...        ...
# 126935                             Better Shelter, Sweden       2010
# 126945                      Thinking Machines Corporation       1987
# 128244                                   Daniel Libeskind       1987
# 128809                                         Dan Graham  2015-2016
# 129350                                     Tauba Auerbach       2015
#
#                                                    Medium  \
# 862                                                  Wood
# 864                                      Acrylic and wood
# 869     Plywood, plastic, paper, sand, wood, metal, an...
# 871                                               Plastic
# 872                                                   NaN
# ...                                                   ...
# 126935  Steel frame, polyolefin envelope, polypropylen...
# 126945                 Steel, plexiglass, and electronics
# 128244          Painted wood, wire, plexiglass, and paper
# 128809  Two-way mirror glass, stainless steel and perf...
# 129350  3D printed nylon and plastic on table of alumi...
#
#                                                Dimensions Acquisition Date  \
# 862       4 1/2 x 2 1/2 x 48 7/8" (11.4 x 6.4 x 124.2 cm)       1997-01-15
# 864     34 1/2 x 23 7/8 x 58 3/8" (87.6 x 60.6 x 148.3...       1981-01-08
# 869        15 1/8 x 36 1/2 x 59" (38.4 x 92.7 x 149.9 cm)       1996-04-09
# 871        11 x 37 1/2 x 47 3/8" (27.9 x 95.3 x 120.3 cm)       1984-10-30
# 872     13 1/2 x 54 1/2 x 63 3/4" (34.3 x 138.4 x 162 cm)       1984-10-30
# ...                                                   ...              ...
# 126935  223 5/8 × 130 11/16 × 111 7/16" (568 × 332 × 2...       2016-02-22
# 126945           62 × 58 × 57" (157.5 × 147.3 × 144.8 cm)       2016-02-22
# 128244    15 3/4 × 30 11/16 × 57 1/16" (40 × 78 × 145 cm)       2016-06-10
# 128809  97 1/2 × 211 × 180 1/2" (247.7 × 535.9 × 458.5...       2016-06-06
# 129350  116 parts ranging from 18 × 18 × 10” (45.7 × 4...       2016-12-12
#
#                                                    Credit Catalogue  ...  \
# 862     Given anonymously and David Rockefeller, Jr. P...         Y  ...
# 864          Best Products Company Inc. Architecture Fund         Y  ...
# 869                                     Given anonymously         Y  ...
# 871                                Gift of the architects         Y  ...
# 872                                Gift of the architects         N  ...
# ...                                                   ...       ...  ...
# 126935                             Gift of Better Shelter         Y  ...
# 126945   Gift of The Aaron and Betty Lee Stern Foundation         Y  ...
# 128244                              Gift of the architect         Y  ...
# 128809  Gift of the Committee on Painting and Sculptur...         Y  ...
# 129350  Acquired through the generosity of Jerry Speye...         Y  ...
#
#        Height (cm) Length (cm)  Width (cm)  Depth (cm)  Weight (kg)  \
# 862      11.400000         NaN    6.400000  124.200000          NaN
# 864      87.630200         NaN   60.642600  148.272800          NaN
# 869      38.417600         NaN   92.710200  149.860300          NaN
# 871      27.940100         NaN   95.250200  120.332700          NaN
# 872      34.290100         NaN  138.430300  162.000000          NaN
# ...            ...         ...         ...         ...          ...
# 126935  568.000000         NaN  332.000000  283.000000          NaN
# 126945  157.480315         NaN  147.320295  144.780290          NaN
# 128244   40.000000         NaN   78.000000  145.000000          NaN
# 128809  247.650495         NaN  535.941072  458.470917          NaN
# 129350   38.100076         NaN  274.320549  274.320549          NaN
#
#         Duration (s)  acquisitionYear  Medium_agg  medium_agg        surface
# 862              NaN             1997       other         NaN      72.960000
# 864              NaN             1981       other        wood    5314.123167
# 869              NaN             1996       other        wood    3561.703380
# 871              NaN             1984       other         NaN    2661.300113
# 872              NaN             1984       other         NaN    4746.788830
# ...              ...              ...         ...         ...            ...
# 126935           NaN             2016       other         NaN  188576.000000
# 126945           NaN             2016       other         NaN   23200.046400
# 128244           NaN             2016       other        wood    3120.000000
# 128809           NaN             2016       other         NaN  132726.071904
# 129350           NaN             2016       other        wood   10451.633807
#
# [318 rows x 25 columns]

# %%
# For surface area
Atgetless_artworks[['medium_agg', 'surface']].boxplot(by='medium_agg', figsize=(10,20))
plt.show()

# %%
Atgetless_artworks[Atgetless_artworks['surface']>2000]
# Out:
#         Artwork ID                                              Title  \
# 0                2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 3                5  The Manhattan Transcripts Project, New York, N...
# 30              32  Memorial to the Six Million Jewish Martyrs, pr...
# 31              33  The Manhattan Transcripts Project, New York, N...
# 33              35  The Manhattan Transcripts Project, New York, N...
# ...            ...                                                ...
# 130197      217761  Exhibition House, German Building Exhibition, ...
# 130198      217762  Exhibition House, German Building Exhibition, ...
# 130199      217763  Exhibition House, German Building Exhibition, ...
# 130200      217764  Exhibition House, German Building Exhibition, ...
# 130201      217765  Exhibition House, German Building Exhibition, ...
#
#        Artist ID                      Name       Date  \
# 0           6210               Otto Wagner       1896
# 3           7056           Bernard Tschumi       1980
# 30          2964             Louis I. Kahn       1968
# 31          7056           Bernard Tschumi       1980
# 33          7056           Bernard Tschumi       1978
# ...          ...                       ...        ...
# 130197      7166  Ludwig Mies van der Rohe  1930–1931
# 130198      7166  Ludwig Mies van der Rohe  1930–1931
# 130199      7166  Ludwig Mies van der Rohe  1930–1931
# 130200      7166  Ludwig Mies van der Rohe  1930–1931
# 130201      7166  Ludwig Mies van der Rohe  1930–1931
#
#                                                    Medium  \
# 0           Ink and cut-and-pasted painted pages on paper
# 3       Photographic reproduction with colored synthet...
# 30                 Charcoal and graphite on tracing paper
# 31      Photographic reproduction with colored synthet...
# 33      Ink, charcoal, graphite, cut-and-pasted photog...
# ...                                                   ...
# 130197                            Pencil on tracing paper
# 130198                            Pencil on tracing paper
# 130199                            Pencil on tracing paper
# 130200                            Pencil on tracing paper
# 130201                            Pencil on tracing paper
#
#                                 Dimensions Acquisition Date  \
# 0       19 1/8 x 66 1/2" (48.6 x 168.9 cm)       1996-04-09
# 3                20 x 20" (50.8 x 50.8 cm)       1995-01-17
# 30           44 1/2 x 66" (113 x 167.6 cm)       1997-01-15
# 31               20 x 20" (50.8 X 50.8 cm)       1995-01-17
# 33               24 x 322" (61 x 817.9 cm)       1995-01-17
# ...                                    ...              ...
# 130197         26 3/4 × 37" (67.9 × 94 cm)              NaN
# 130198       29 × 35 1/2" (73.7 × 90.2 cm)              NaN
# 130199       21 × 38 1/4" (53.3 × 97.2 cm)              NaN
# 130200      17 × 46 1/4" (43.2 × 117.5 cm)              NaN
# 130201   28 1/4 × 33 1/2" (71.8 × 85.1 cm)              NaN
#
#                                                    Credit Catalogue  ...  \
# 0       Fractional and promised gift of Jo Carole and ...         Y  ...
# 3       Purchase and partial gift of the architect in ...         Y  ...
# 30                                               Purchase         Y  ...
# 31      Purchase and partial gift of the architect in ...         Y  ...
# 33      Purchase and partial gift of the architect in ...         Y  ...
# ...                                                   ...       ...  ...
# 130197  Mies van der Rohe Archive, gift of the archite...         Y  ...
# 130198  Mies van der Rohe Archive, gift of the archite...         Y  ...
# 130199  Mies van der Rohe Archive, gift of the archite...         Y  ...
# 130200  Mies van der Rohe Archive, gift of the archite...         Y  ...
# 130201  Mies van der Rohe Archive, gift of the archite...         Y  ...
#
#        Height (cm) Length (cm)  Width (cm)  Depth (cm)  Weight (kg)  \
# 0        48.600000         NaN  168.900000         NaN          NaN
# 3        50.800000         NaN   50.800000         NaN          NaN
# 30      113.000000         NaN  167.600000         NaN          NaN
# 31       50.800000         NaN   50.800000         NaN          NaN
# 33       60.960100         NaN  817.881600         NaN          NaN
# ...            ...         ...         ...         ...          ...
# 130197   67.945136         NaN   93.980188         NaN          NaN
# 130198   73.660147         NaN   90.170180         NaN          NaN
# 130199   53.340107         NaN   97.155194         NaN          NaN
# 130200   43.180086         NaN  117.475235         NaN          NaN
# 130201   71.755144         NaN   85.090170         NaN          NaN
#
#         Duration (s)  acquisitionYear  Medium_agg  medium_agg       surface
# 0                NaN             1996       other       paper   8208.540000
# 3                NaN             1995       other         NaN   2580.640000
# 30               NaN             1997       other       paper  18938.800000
# 31               NaN             1995       other         NaN   2580.640000
# 33               NaN             1995       other       photo  49858.144124
# ...              ...              ...         ...         ...           ...
# 130197           NaN                0       other       paper   6385.496642
# 130198           NaN                0       other       paper   6641.948768
# 130199           NaN                0       other       paper   5182.268429
# 130200           NaN                0       other       paper   5072.590790
# 130201           NaN                0       other       paper   6105.657373
#
# [26619 rows x 25 columns]
